# %%
import pandas as pd
from torch.utils.data import Dataset


class CifarDataset(Dataset):
    def __init__(self, image_ids):
        with open(image_ids, 'r') as f:
            data = csv.reader(f)
            next(data)
            for row in data:
                row[0]
                break

    def __len__(self):
        raise NotImplementedError

    def __getitem__(self):
        raise NotImplementedError


trainset = CifarDataset('inputs/trainLabels.csv')
trainser[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-cd32a1903cc2> in <module>()
#      18         raise NotImplementedError
#      19
# ---> 20 trainset = CifarDataset('inputs/trainLabels.csv')
#      21 trainser[0]
#
# <ipython-input-3-cd32a1903cc2> in __init__(self, image_ids)
#       5 class CifarDataset(Dataset):
#       6     def __init__(self, image_ids):
# ----> 7         with open(image_ids, 'r') as f:
#       8             data = csv.reader(f)
#       9             next(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'inputs/trainLabels.csv'
