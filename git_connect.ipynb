# %%
from google.colab import drive

drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import os

path = '/content/gdrive/MyDrive/Colab Notebooks'
os.chdir(path)
git_repo_path = os.path.join(path, '2021-AI-study')
os.chdir(git_repo_path)
print('current dir:', os.getcwd())
# Out:
# current dir: /content/gdrive/MyDrive/Colab Notebooks/2021-AI-study

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/MyDrive/Colab Notebooks/2021-AI-study/.git/

# %%
# !git remote rm origin

# %%
# !git remote add origin 'https://leeyeoreum02:dnsldh55!!@github.com/leeyeoreum02/2021-AI-study.git/'

# %%
# !git pull origin master --allow-unrelated-histories
# Out:
# From https://github.com/leeyeoreum02/2021-AI-study
#  * branch            master     -> FETCH_HEAD
# error: Your local changes to the following files would be overwritten by merge:
# 	README.md
# Please commit your changes or stash them before you merge.
# Aborting

# %%
# !git config --global user.email 'leeyeoreum01@gmail.com'
# !git config --global user.name 'leeyeoreum02'

# %%
# !git add .

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   git_connect.ipynb

# %%
# !git commit -m '1/26 test'
# Out:
# [master a3b4ff5] 1/26 test
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git_connect.ipynb (77%)

# %%
# !git push -f origin master
# Out:
# Counting objects: 12, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (12/12), 30.25 KiB | 1.32 MiB/s, done.
# Total 12 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), done.
# To https://github.com/leeyeoreum02/2021_AI_study.git
#  + cbef60b...9c14d0c master -> master (forced update)

# %%
# !git add '.gitignore'
# !git commit -m "update .gitignore ./data"
# !git push origin master
# Out:
# fatal: pathspec '.gitignore' did not match any files
# On branch master
# Changes not staged for commit:
# 	modified:   Landmark classification.ipynb
# 	modified:   git_connect.ipynb
#
# Untracked files:
# 	VGG16+CIFAR10.ipynb
#
# no changes added to commit
# To https://github.com/leeyeoreum02/2021_AI_study.git
#  ! [rejected]        master -> master (fetch first)
# error: failed to push some refs to 'https://leeyeoreum02:dnsldh55!!@github.com/leeyeoreum02/2021_AI_study.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git filter-branch --force --index-filter "git rm --cached --ignore-unmatch './data'" --prune-empty --tag-name-filter cat -- --all
# Out:
# Cannot rewrite branches: You have unstaged changes.

# %%
# !git reset HEAD^
# Out:
# fatal: ambiguous argument 'HEAD^': unknown revision or path not in the working tree.
# Use '--' to separate paths from revisions, like this:
# 'git <command> [<revision>...] -- [<file>...]'

# %%
# !git commit -m "1/26 test"
# !git push origin master -f
# Out:
# On branch master
# Changes not staged for commit:
# 	modified:   Landmark classification.ipynb
# 	modified:   git_connect.ipynb
#
# Untracked files:
# 	VGG16+CIFAR10.ipynb
# 	data/
#
# no changes added to commit
# Everything up-to-date

# %%
# Out:
# /bin/bash: vim: command not found
